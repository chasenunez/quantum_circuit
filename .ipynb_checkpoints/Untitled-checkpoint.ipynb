# %%
# %pip install qiskit
# Out:
# Collecting qiskit
#   Using cached qiskit-2.3.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Using cached rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /opt/homebrew/lib/python3.14/site-packages (from qiskit) (2.4.1)
# Collecting scipy>=1.5 (from qiskit)
#   Downloading scipy-1.17.0-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting dill>=0.3 (from qiskit)
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.6.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in /opt/homebrew/Cellar/jupyterlab/4.5.0_2/libexec/lib/python3.14/site-packages (from qiskit) (4.15.0)
# Downloading qiskit-2.3.0-cp310-abi3-macosx_11_0_arm64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 73.6 MB/s  0:00:00
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl (2.0 MB)
# Downloading scipy-1.17.0-cp314-cp314-macosx_14_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 69.1 MB/s  0:00:000.2 MB/s eta 0:00:01
# Downloading stevedore-5.6.0-py3-none-any.whl (54 kB)
# Installing collected packages: stevedore, scipy, rustworkx, dill, qiskit
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [qiskit]━━━━ 4/5 [qiskit]
# Successfully installed dill-0.4.1 qiskit-2.3.0 rustworkx-0.17.1 scipy-1.17.0 stevedore-5.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from qiskit import QuantumCircuit
from qiskit.primitives import StatevectorSampler

qc = QuantumCircuit(3)
qc.h(0)
qc.cx(1,2)
qc.measure_all()

sampler = StatevectorSampler()
result = sampler.run([qc], shots=1024).result()
print(result[0].data.meas.get_counts())

# Uncomment lines 14 and 20 if you are not using Python in a Jupyter notebook
# import matplotlib.pyplot as plt
from qiskit.visualization import plot_histogram
 
counts = result[0].data.meas.get_counts()
plot_histogram(counts)
 
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[8], line 11
#       8 qc.x(1)
#      10 sampler = StatevectorSampler()
# ---> 11 result = sampler.run([qc], shots=1024).result()
#      12 print(result[0].data.meas.get_counts())
#      14 # Uncomment lines 14 and 20 if you are not using Python in a Jupyter notebook
#      15 # import matplotlib.pyplot as plt
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.0_2/libexec/lib/python3.14/site-packages/qiskit/primitives/primitive_job.py:70, in PrimitiveJob.result(self)
#      68 if self._result is None:
#      69     self._check_submitted()
# ---> 70     self._result = self._future.result()
#      71 return self._result
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.2/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.0_2/libexec/lib/python3.14/site-packages/qiskit/primitives/statevector_sampler.py:174, in StatevectorSampler._run(self, pubs)
#     173 def _run(self, pubs: Iterable[SamplerPub]) -> PrimitiveResult[SamplerPubResult]:
# --> 174     results = [self._run_pub(pub) for pub in pubs]
#     175     return PrimitiveResult(results, metadata={"version": 2})
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.0_2/libexec/lib/python3.14/site-packages/qiskit/primitives/statevector_sampler.py:178, in StatevectorSampler._run_pub(self, pub)
#     177 def _run_pub(self, pub: SamplerPub) -> SamplerPubResult:
# --> 178     circuit, qargs, meas_info = _preprocess_circuit(pub.circuit)
#     179     bound_circuits = pub.parameter_values.bind_all(circuit)
#     180     arrays = {
#     181         item.creg_name: np.zeros(
#     182             bound_circuits.shape + (pub.shots, item.num_bytes), dtype=np.uint8
#     183         )
#     184         for item in meas_info
#     185     }
#
# File /opt/homebrew/Cellar/jupyterlab/4.5.0_2/libexec/lib/python3.14/site-packages/qiskit/primitives/statevector_sampler.py:216, in _preprocess_circuit(circuit)
#     214     raise QiskitError("StatevectorSampler cannot handle ControlFlowOp")
#     215 if _has_measure(circuit):
# --> 216     raise QiskitError("StatevectorSampler cannot handle mid-circuit measurements")
#     217 # num_qubits is used as sentinel to fill 0 in _samples_to_packed_array
#     218 sentinel = len(qargs)
#
# QiskitError: 'StatevectorSampler cannot handle mid-circuit measurements'
